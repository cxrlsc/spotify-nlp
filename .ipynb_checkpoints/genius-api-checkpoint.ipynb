# %%
pip install lyricsgenius -q

# %%
from lyricsgenius import Genius
import pandas as pd

# %%
token = "rr7YGMkarmjd_A6hUH4C_gNS46amqPOjoWUGqF1wU1UQkzwqGQ8_OHdl32h8WTrr"
genius = Genius(token, 
                skip_non_songs=True, 
                excluded_terms=["(Remix)", "(Live)"], 
                remove_section_headers=True)

# %%
data = pd.DataFrame({
    'artist': [],
    'title': [],
    'lyrics': [],
    'description': [],
    'release date': []
})
data
# Out:
# Empty DataFrame
# Columns: [artist, title, lyrics, description, release date]
# Index: []

# %%
# Small example
songs = genius.search_artist("Gunna", max_songs=2, sort="popularity").songs
# Out:
# Searching for songs by Gunna...
#
# Song 1: "Oh Okay"
# "Hot (Remix)" is not valid. Skipping.
# Song 2: "Sold Out Dates"
#
# Reached user-specified song limit (2).
# Done. Found 2 songs.

# %%
def extract_songs_data(songs):
    tbl = pd.DataFrame()
    for song in songs:
        # example_data.append(song.lyrics)

        song_dict = song.to_dict()
        song_artist = song_dict["primary_artist"]["name"]
        song_title = song_dict["title"]
        song_lyrics = song_dict["lyrics"]
        song_descpt = song_dict["description"]
        song_release_date = song_dict["release_date_for_display"]

        temp_data = pd.DataFrame({
            'artist': song_artist,
            'title': song_title,
            'lyrics': song_lyrics,
            'description': song_descpt,
            'release date': song_release_date
        })
        
        tbl = tbl.append(temp_data, ignore_index=True)
        
    return tbl
    #data = data.append(temp_data, ignore_index=True)

# %%
artist_lst = ["Ray Charles", "Ken Nordine", "Ghetto Brothers", "Sugarhill Gang & The Furious Five", 
              "Busy Bee Starski", "N.W.A", "Ice Cube", "The Notorious B.I.G.", "50 Cent", "Gunna",
              "The Beach Boys", "The Monkees", "Elvis Presley", "Elton John", "Cyndi Lauper", 
              "The Bangles", "Duran Duran", "Spice Girls", "Fergie", "Olivia Rodrigo", "The Temptations", 
              "The Supremes", "The O’Jays", "The Jackson 5", "Diana Ross", "The Gap Band", "DeBarge", 
              "Tony! Toni! Toné!", "Mariah Carey", "Frank Ocean", "The Velvet Underground", "The Sonics", 
              "David Bowie", "The Who", "The Smiths", "Pixies", "Weezer", "The Cranberries", "Arctic Monkeys", 
              "Foster The People", "Vanilla Fudge", "Blue Cheer", "Black Sabbath", "Led Zeppelin", "Kiss", 
              "Iron Maiden", "Metallica", "Slayer", "Slipknot", "System of a Down", "The Beatles", 
              "The Rolling Stones",  "The Doors", "Pink Floyd", "Guns N’ Roses", "Queen", "Nirvana", 
              "Blink-182", "Paramore", "Red Hot Chili Peppers", "Silver Apples", "Fifty Foot Hose",
              "Tangerine Dream", "Jean-Michel Jarre", "Kraftwerk", "Erasure", "Boards of Canada", 
              "The Prodigy", "Carl Cox", "Boris Brejcha", "Patsy Cline", "Johnny Cash", "Dolly Parton", 
              "Willie Nelson", "Loretta Lynn", "Kenny Rogers", "The Chicks", "Brooks & Dunn", 
              "Carrie Underwood", "Luke Bryan",
             ]

# %% [markdown]
# Let us see how many artists we have.

# %%
len(artist_lst)
# Out:
# 80

# %% [markdown]
# We have 80 artists, 10 artists per genre, 2 artists per decade. There are 8 genres. Now, let's collect the top 3 songs for each of these artists. This means that our data will contain information from $80 \times 3 = 240$ songs.

# %%
num_songs = 3
for artist in artist_lst[23:]:  
    try: 
        genius = Genius(token, 
                        skip_non_songs=True, 
                        excluded_terms=["(Remix)", "(Live)"], 
                        remove_section_headers=True)
        songs = genius.search_artist(artist, max_songs=num_songs, sort="popularity").songs
        new_data = extract_songs_data(songs)
        
        data = data.append(new_data, ignore_index=True)
        
    except: 
        genius = Genius(token, 
                        skip_non_songs=True, 
                        excluded_terms=["(Remix)", "(Live)"], 
                        remove_section_headers=True)
        
        songs = genius.search_artist(artist, max_songs=num_songs, sort="popularity").songs
        new_data = extract_songs_data(songs)
        
        data = data.append(new_data, ignore_index=True)
# Out:
# Searching for songs by The Jackson 5...
#
# Song 1: "I Want You Back"
# Song 2: "ABC"
# Searching for songs by The Jackson 5...
#
# Song 1: "I Want You Back"
# Song 2: "ABC"
# Song 3: "I’ll Be There"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Diana Ross...
#
# Song 1: "I’m Coming Out"
# Song 2: "Upside Down"
# Song 3: "Ain’t No Mountain High Enough"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by The Gap Band...
#
# Song 1: "Outstanding"
# Song 2: "You Dropped a Bomb on Me"
# Song 3: "Yearning for Your Love"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by DeBarge...
#
# Song 1: "I Like It"
# Song 2: "Rhythm of the Night"
# Song 3: "A Dream"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Tony! Toni! Toné!...
#
# Song 1: "Anniversary"
# Song 2: "Whatever You Want"
# Song 3: "It Never Rains (In Southern California)"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Mariah Carey...
#
# Song 1: "All I Want for Christmas Is You"
# Song 2: "We Belong Together"
# Song 3: "Obsessed"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Frank Ocean...
#
# Song 1: "Thinkin Bout You"
# Song 2: "Nights"
# Song 3: "Self Control"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by The Velvet Underground...
#
# Song 1: "Heroin"
# Song 2: "Sunday Morning"
# Song 3: "Pale Blue Eyes"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by The Sonics...
#
# Song 1: "Have Love, Will Travel"
# Song 2: "The Witch"
# Song 3: "Strychnine"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by David Bowie...
#
# Searching for songs by David Bowie...
#
# Song 1: "Space Oddity"
# Song 2: "“Heroes”"
# Song 3: "★ (Blackstar)"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by The Who...
#
# Song 1: "Baba O’Riley"
# Song 2: "Who Are You"
# Song 3: "Behind Blue Eyes"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by The Smiths...
#
# Song 1: "There Is a Light That Never Goes Out"
# Song 2: "This Charming Man"
# Song 3: "I Know It’s Over"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Pixies...
#
# Song 1: "Where Is My Mind?"
# Song 2: "Hey"
# Song 3: "Debaser"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Weezer...
#
# Song 1: "Say It Ain’t So"
# Song 2: "Buddy Holly"
# Song 3: "Island in the Sun"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by The Cranberries...
#
# Song 1: "Zombie"
# Song 2: "Linger"
# Song 3: "Dreams"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Arctic Monkeys...
#
# Song 1: "Do I Wanna Know?"
# Song 2: "505"
# Song 3: "Fluorescent Adolescent"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Foster The People...
#
# Changing artist name to 'Foster the People'
# Song 1: "Pumped Up Kicks"
# Song 2: "Sit Next to Me"
# Song 3: "Houdini"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Vanilla Fudge...
#
# Song 1: "You Keep Me Hangin’ On"
# Song 2: "You Keep Me Hangin’ On (Single Version)"
# Song 3: "Take Me for a Little While"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Blue Cheer...
#
# Song 1: "Peace of Mind"
# Song 2: "Summertime Blues"
# Song 3: "Out of Focus"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Black Sabbath...
#
# Song 1: "Paranoid"
# Song 2: "Iron Man"
# Song 3: "War Pigs"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Led Zeppelin...
#
# Song 1: "Stairway to Heaven"
# Song 2: "Immigrant Song"
# Song 3: "Kashmir"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Kiss...
#
# Song 1: "I Was Made for Lovin’ You"
# Song 2: "Rock and Roll All Nite"
# Song 3: "Detroit Rock City"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Iron Maiden...
#
# Song 1: "The Number of the Beast"
# Song 2: "Fear of the Dark"
# Song 3: "The Trooper"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Metallica...
#
# Song 1: "Nothing Else Matters"
# Song 2: "One"
# Song 3: "Enter Sandman"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Slayer...
#
# Song 1: "Angel of Death"
# Song 2: "Raining Blood"
# Song 3: "Dead Skin Mask"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Slipknot...
#
# Song 1: "Snuff"
# Song 2: "Psychosocial"
# Song 3: "Duality"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by System of a Down...
#
# Song 1: "Chop Suey!"
# Song 2: "Toxicity"
# Song 3: "B.Y.O.B."
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by The Beatles...
#
# Song 1: "Let It Be"
# Song 2: "Yesterday"
# Searching for songs by The Beatles...
#
# Song 1: "Let It Be"
# Song 2: "Yesterday"
# Song 3: "Come Together"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by The Rolling Stones...
#
# Song 1: "Sympathy for the Devil"
# Searching for songs by The Rolling Stones...
#
# Song 1: "Sympathy for the Devil"
# Song 2: "Paint It, Black"
# Song 3: "Brown Sugar"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by The Doors...
#
# Song 1: "The End"
# Song 2: "Riders on the Storm"
# Song 3: "Light My Fire"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Pink Floyd...
#
# Song 1: "Wish You Were Here"
# Song 2: "Time"
# Song 3: "Comfortably Numb"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Guns N’ Roses...
#
# Song 1: "Sweet Child O’ Mine"
# Song 2: "Welcome to the Jungle"
# Song 3: "November Rain"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Queen...
#
# Searching for songs by Queen...
#
# Song 1: "Bohemian Rhapsody"
# Song 2: "Don’t Stop Me Now"
# Song 3: "Love of My Life"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Nirvana...
#
# Searching for songs by Nirvana...
#
# Song 1: "Smells Like Teen Spirit"
# Song 2: "Come as You Are"
# Song 3: "Heart-Shaped Box"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Blink-182...
#
# Changing artist name to '​​blink-182'
# Song 1: "I Miss You"
# Song 2: "All the Small Things"
# Song 3: "What’s My Age Again?"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Paramore...
#
# Song 1: "Still into You"
# Song 2: "Hard Times"
# Song 3: "Misery Business"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Red Hot Chili Peppers...
#
# Song 1: "Californication"
# Song 2: "Under the Bridge"
# Song 3: "Can’t Stop"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Silver Apples...
#
# Song 1: "Program"
# Song 2: "I Have Known Love"
# Song 3: "Oscillations"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Fifty Foot Hose...
#
# Song 1: "Rose"
# Song 2: "If Not This Time"
# Song 3: "Fantasy"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Tangerine Dream...
#
# Song 1: "Bent Cold Sidewalk"
# Song 2: "Tyger"
# Song 3: "Wish You Were Here"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Jean-Michel Jarre...
#
# Song 1: "Exit"
# Song 2: "Millions of Stars"
# Song 3: "Suns Have Gone"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Kraftwerk...
#
# Song 1: "Das Modell"
# Song 2: "Autobahn"
# Song 3: "The Robots"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Erasure...
#
# Song 1: "A Little Respect"
# Song 2: "Always"
# Song 3: "Love to Hate You"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Boards of Canada...
#
# Song 1: "1969"
# Song 2: "Aquarius"
# Song 3: "Roygbiv"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by The Prodigy...
#
# Song 1: "Firestarter"
# Song 2: "Breathe"
# Song 3: "Smack My Bitch Up"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Carl Cox...
#
# "I Want You (Forever) [Josh Butler Remix]" is not valid. Skipping.
# "I Want You (Forever) [deadmau5 Remix]" is not valid. Skipping.
# Song 1: "We Rob Together by Carl Cox"
# Song 2: "Give Me Your Love"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Round-table-knights-calypso-lyrics
# "Pomegranate (Carl Cox Remix)" is not valid. Skipping.
# Song 3: "Nexus"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Boris Brejcha...
#
# Song 1: "Gravity"
# Song 2: "Happinezz"
# Song 3: "Take It Smart"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Patsy Cline...
#
# Song 1: "Crazy"
# Song 2: "You Belong to Me"
# Song 3: "Walkin’ After Midnight"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Johnny Cash...
#
# Song 1: "You Are My Sunshine"
# Song 2: "Hurt"
# Song 3: "Ring of Fire"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Dolly Parton...
#
# Searching for songs by Dolly Parton...
#
# Song 1: "Jolene"
# Song 2: "9 to 5"
# Song 3: "Coat of Many Colors"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Willie Nelson...
#
# Song 1: "Cruel World"
# Song 2: "On the Road Again"
# Song 3: "Blue Eyes Crying in the Rain"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Loretta Lynn...
#
# Song 1: "The Pill"
# Song 2: "You Ain’t Woman Enough (To Take My Man)"
# Song 3: "Louisiana Woman, Mississippi Man"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Kenny Rogers...
#
# Song 1: "The Gambler"
# Song 2: "Coward of the County"
# Song 3: "Lady"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by The Chicks...
#
# Song 1: "Gaslighter"
# Song 2: "Travelin’ Soldier"
# Song 3: "March March"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Brooks & Dunn...
#
# Song 1: "Neon Moon"
# Song 2: "You’re Gonna Miss Me When I’m Gone"
# Song 3: "Red Dirt Road"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Carrie Underwood...
#
# Searching for songs by Carrie Underwood...
#
# Song 1: "Before He Cheats"
# Song 2: "Cry Pretty"
# Song 3: "The Champion"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# Searching for songs by Luke Bryan...
#
# Song 1: "Most People Are Good"
# Song 2: "What She Wants Tonight"
# Song 3: "That’s My Kind of Night"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.

# %%
data
# Out:
#                artist                    title  \
# 0         Ray Charles        Hit the Road Jack
# 1         Ray Charles       Georgia On My Mind
# 2         Ray Charles         I’ve Got a Woman
# 3         Ken Nordine                   Yellow
# 4         Ken Nordine                    Green
# ..                ...                      ...
# 233  Carrie Underwood               Cry Pretty
# 234  Carrie Underwood             The Champion
# 235        Luke Bryan     Most People Are Good
# 236        Luke Bryan   What She Wants Tonight
# 237        Luke Bryan  That’s My Kind of Night
#
#                                                 lyrics  \
# 0    Hit the Road Jack Lyrics\nHit the road Jack, a...
# 1    Georgia On My Mind Lyrics\nGeorgia\nGeorgia\nT...
# 2    I’ve Got a Woman Lyrics\nWell\n\nI got a woman...
# 3    Yellow LyricsIn the beginning--\nOh, long befo...
# 4    Green LyricsAs an intellectual vibration smack...
# ..                                                 ...
# 233  Cry Pretty Lyrics\nI'm sorry, but I'm just a g...
# 234  The Champion Lyrics\nI’ll be the last one stan...
# 235  Most People Are Good Lyrics\nI believe kids ou...
# 236  What She Wants Tonight Lyrics\nShe walks up, v...
# 237  That’s My Kind of Night Lyrics\nI got that rea...
#
#                                            description      release date
# 0    This tongue and cheek verbal duel of a couple ...       August 1961
# 1    Written by Hoagy Carmichael and Stuart Gorrell...    September 1960
# 2    Ray Charles released “I’ve Got a Woman” as a s...     December 1954
# 3                                                    ?   January 1, 1966
# 4                                                    ?   January 1, 1966
# ..                                                 ...               ...
# 233  This song follows Underwood’s journey of comin...    April 11, 2018
# 234  On the 6th of January 2018, “Champion” was off...  January 12, 2018
# 235  This song is quirky and awesome everyone shoul...  November 3, 2017
# 236                                                  ?  October 25, 2019
# 237  Luke Bryan’s second single from 2013’s ‘Crash ...       August 2013
#
# [238 rows x 5 columns]

# %%
no_descriptions = data[data['description'] == "?"]
no_descriptions
# Out:
#                                 artist  \
# 3                          Ken Nordine
# 4                          Ken Nordine
# 5                          Ken Nordine
# 7                      Ghetto Brothers
# 8                      Ghetto Brothers
# 9    Sugarhill Gang & The Furious Five
# 10                            Busy Bee
# 11                            Busy Bee
# 33                         The Monkees
# 60                     The Temptations
# 63                        The Supremes
# 75                        The Gap Band
# 77                             DeBarge
# 80                   Tony! Toni! Toné!
# 81                   Tony! Toni! Toné!
# 118                      Vanilla Fudge
# 119                      Vanilla Fudge
# 120                      Vanilla Fudge
# 123                         Blue Cheer
# 178                      Silver Apples
# 179                      Silver Apples
# 181                    Fifty Foot Hose
# 182                    Fifty Foot Hose
# 183                    Fifty Foot Hose
# 184                    Tangerine Dream
# 186                    Tangerine Dream
# 187                  Jean-Michel Jarre
# 188                  Jean-Michel Jarre
# 189                  Jean-Michel Jarre
# 190                          Kraftwerk
# 194                            Erasure
# 196                   Boards of Canada
# 202                           Carl Cox
# 203                           Carl Cox
# 204                           Carl Cox
# 206                      Boris Brejcha
# 207                      Boris Brejcha
# 209                        Patsy Cline
# 210                        Patsy Cline
# 221                       Loretta Lynn
# 222                       Loretta Lynn
# 236                         Luke Bryan
#
#                                        title  \
# 3                                     Yellow
# 4                                      Green
# 5                           What Time Is It?
# 7             There Is Something In My Heart
# 8                      Ghetto Brothers Power
# 9                           Someone Like You
# 10                                Old School
# 11                         Making Cash Money
# 33                            Me & Magdalena
# 60                              Silent Night
# 63                 Stop! In the Name of Love
# 75                    Yearning for Your Love
# 77                       Rhythm of the Night
# 80                         Whatever You Want
# 81   It Never Rains (In Southern California)
# 118                   You Keep Me Hangin’ On
# 119  You Keep Me Hangin’ On (Single Version)
# 120               Take Me for a Little While
# 123                             Out of Focus
# 178                                  Program
# 179                        I Have Known Love
# 181                                     Rose
# 182                         If Not This Time
# 183                                  Fantasy
# 184                       Bent Cold Sidewalk
# 186                       Wish You Were Here
# 187                                     Exit
# 188                        Millions of Stars
# 189                           Suns Have Gone
# 190                               Das Modell
# 194                                   Always
# 196                                     1969
# 202              We Rob Together by Carl Cox
# 203                        Give Me Your Love
# 204                                    Nexus
# 206                                Happinezz
# 207                            Take It Smart
# 209                         You Belong to Me
# 210                   Walkin’ After Midnight
# 221  You Ain’t Woman Enough (To Take My Man)
# 222         Louisiana Woman, Mississippi Man
# 236                   What She Wants Tonight
#
#                                                 lyrics description  \
# 3    Yellow LyricsIn the beginning--\nOh, long befo...           ?
# 4    Green LyricsAs an intellectual vibration smack...           ?
# 5    What Time Is It? LyricsThere was this guy who ...           ?
# 7    There Is Something In My Heart LyricsThere is ...           ?
# 8    Ghetto Brothers Power LyricsAhora sí\nWe are g...           ?
# 9    Someone Like You Lyrics\nSomeone like you\n\nS...           ?
# 10   Old School Lyrics\nOoooooooh\nWeeeeeeee!\nOh, ...           ?
# 11   Making Cash Money Lyrics\nHey y'all\nI want ev...           ?
# 33   Me & Magdalena Lyrics\nMe and Magdalena\nWe're...           ?
# 60   Silent Night Lyrics'Twas the night before Chri...           ?
# 63   Stop! In the Name of Love Lyrics\nStop in the ...           ?
# 75   Yearning for Your Love Lyrics\nThe time has co...           ?
# 77   Rhythm of the Night Lyrics\nWhen it feels like...           ?
# 80   Whatever You Want Lyrics\nI don't wish you no ...           ?
# 81   It Never Rains (In Southern California) Lyrics...           ?
# 118  You Keep Me Hangin’ On Lyrics\nSet me free, wh...           ?
# 119  You Keep Me Hangin’ On (Single Version) Lyrics...           ?
# 120  Take Me for a Little While Lyrics\nI've been t...           ?
# 123  Out of Focus LyricsAlright!\nA cold, cold dark...           ?
# 178  Program LyricsIt was very late last night\nI s...           ?
# 179  I Have Known Love LyricsI have known love and ...           ?
# 181  Rose LyricsSet in plastic for all to see\nBut ...           ?
# 182  If Not This Time Lyrics\nSince time forgot\nTo...           ?
# 183  Fantasy LyricsPlease fantasy\nPlease stay with...           ?
# 184  Bent Cold Sidewalk LyricsWhen I talk to the tr...           ?
# 186  Wish You Were Here LyricsSo, so you think you ...           ?
# 187  Exit Lyrics\nTechnology can actually increase ...           ?
# 188  Millions of Stars LyricsMillions of stars, shi...           ?
# 189  Suns Have Gone LyricsLike the power I saw old ...           ?
# 190  Das Modell Lyrics\nSie ist ein Model und sie s...           ?
# 194  Always Lyrics\nOpen your eyes, I see\nYour eye...           ?
# 196  1969 Lyrics\nAlthough not a follower of hseroK...           ?
# 202  We Rob Together by Carl Cox LyricsI bought you...           ?
# 203  Give Me Your Love LyricsGive me your love...\n...           ?
# 204                  Nexus Lyrics1\n2\n3\n4\n5\n6Embed           ?
# 206  Happinezz LyricsHappiness\nSo this is really s...           ?
# 207  Take It Smart LyricsI take it smart\nEverybody...           ?
# 209  You Belong to Me Lyrics\nSee the pyramids alon...           ?
# 210  Walkin’ After Midnight Lyrics\nI go out walkin...           ?
# 221  You Ain’t Woman Enough (To Take My Man) Lyrics...           ?
# 222  Louisiana Woman, Mississippi Man LyricsHey Lou...           ?
# 236  What She Wants Tonight Lyrics\nShe walks up, v...           ?
#
#           release date
# 3      January 1, 1966
# 4      January 1, 1966
# 5            July 1957
# 7      January 1, 1971
# 8      January 1, 1972
# 9         July 4, 2019
# 10                1988
# 11                1982
# 33                2016
# 60     August 14, 1980
# 63    February 8, 1965
# 75    December 8, 1980
# 77   February 23, 1985
# 80   February 13, 1991
# 81    October 14, 1990
# 118               1967
# 119               1967
# 120        August 1967
# 123               None
# 178          June 1968
# 179      February 1969
# 181               1968
# 182               1968
# 183               1968
# 184     March 10, 1978
# 186      December 2010
# 187     April 15, 2016
# 188   January 24, 2000
# 189   October 12, 2015
# 190   December 7, 1978
# 194     April 11, 1994
# 196  February 13, 2002
# 202               None
# 203               None
# 204               None
# 206    August 16, 2019
# 207               None
# 209     August 7, 1962
# 210  February 11, 1957
# 221           May 1966
# 222       May 28, 1973
# 236   October 25, 2019

# %%
no_descriptions['artist'].value_counts()
# Out:
# Ken Nordine                          3
# Fifty Foot Hose                      3
# Carl Cox                             3
# Jean-Michel Jarre                    3
# Vanilla Fudge                        3
# Busy Bee                             2
# Tony! Toni! Toné!                    2
# Ghetto Brothers                      2
# Boris Brejcha                        2
# Loretta Lynn                         2
# Tangerine Dream                      2
# Patsy Cline                          2
# Silver Apples                        2
# Kraftwerk                            1
# Sugarhill Gang & The Furious Five    1
# Erasure                              1
# The Monkees                          1
# Blue Cheer                           1
# Boards of Canada                     1
# DeBarge                              1
# Luke Bryan                           1
# The Gap Band                         1
# The Supremes                         1
# The Temptations                      1
# Name: artist, dtype: int64

# %% [markdown]
# Now that we have a list of which artists contain songs without descriptions, let's find new artists in the same genre and decade to replace these with.

# %%
artist = "Cold Crush Brothers"
artist in artist_lst
# Out:
# False

# %%
new_artist_lst = [
    "John Coltrane", "The Chainsmokers", "The Grateful Dead", "Hans Zimmer", 
    "Jim Sullivan", "Cold Crush Brothers", 
]

# %% [markdown]
# Replacing the artists with the follwing:
# - Ken Nordine -> John Coltrane
# - Fifty Foot Hose -> The Grateful Dead
# - Carl Cox -> The Chainsmokers
# - Jean-Michael Jarre -> Hans Zimmer
# - Vanilla Fudge -> Jim Sullivan
# - Sugarhill Gang & The Furious Five -> MF Doom
# - Busy Bee -> Cold Crush Brothers

# %%
genius = Genius(token, 
                skip_non_songs=True, 
                excluded_terms=["(Remix)", "(Live)"], 
                remove_section_headers=True)
songs = genius.search_artist(artist, max_songs=5, sort="popularity").songs
new_data = extract_songs_data(songs)
new_data
# Out:
# Searching for songs by Cold Crush Brothers...
#
# Song 1: "Fresh, Wild, Fly and Bold"
# Song 2: "Cold Crush Bros. At The Dixie"
# Song 3: "Punk Rock Rap (Punk Rock Mix)"
# Song 4: "Weekend"
# Song 5: "Yvette"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.
#                 artist                          title  \
# 0  Cold Crush Brothers      Fresh, Wild, Fly and Bold
# 1  Cold Crush Brothers  Cold Crush Bros. At The Dixie
# 2  Cold Crush Brothers  Punk Rock Rap (Punk Rock Mix)
# 3  Cold Crush Brothers                        Weekend
# 4  Cold Crush Brothers                         Yvette
#
#                                               lyrics  \
# 0  Fresh, Wild, Fly and Bold Lyrics\nWell, I'm fr...
# 1  Cold Crush Bros. At The Dixie Lyrics\nBy this ...
# 2  Punk Rock Rap (Punk Rock Mix) Lyrics\nSay Hun,...
# 3  Weekend Lyrics\nEverybody listen to this\nThe ...
# 4  Yvette Lyrics\nHaha, I got a story to tell, an...
#
#                                          description     release date
# 0  A record that doesn’t lack in self-confidence,...             1984
# 1                                                  ?             1983
# 2                                                  ?  January 1, 1983
# 3                                                  ?  January 1, 1982
# 4                                                  ?             None

# %%
sample_to_add = new_data[new_data['description'] != "?"].sample()
sample_to_add
# Out:
#                 artist                      title  \
# 0  Cold Crush Brothers  Fresh, Wild, Fly and Bold
#
#                                               lyrics  \
# 0  Fresh, Wild, Fly and Bold Lyrics\nWell, I'm fr...
#
#                                          description release date
# 0  A record that doesn’t lack in self-confidence,...         1984

# %%
data = data.append(sample_to_add, ignore_index=True)
data
# Out:
#                   artist                       title  \
# 0            Ray Charles           Hit the Road Jack
# 1            Ray Charles          Georgia On My Mind
# 2            Ray Charles            I’ve Got a Woman
# 3            Ken Nordine                      Yellow
# 4            Ken Nordine                       Green
# ..                   ...                         ...
# 252         Jim Sullivan  Plain As Your Eyes Can See
# 253              MF DOOM                    One Beer
# 254              MF DOOM         Rapp Snitch Knishes
# 255              MF DOOM                 That’s That
# 256  Cold Crush Brothers   Fresh, Wild, Fly and Bold
#
#                                                 lyrics  \
# 0    Hit the Road Jack Lyrics\nHit the road Jack, a...
# 1    Georgia On My Mind Lyrics\nGeorgia\nGeorgia\nT...
# 2    I’ve Got a Woman Lyrics\nWell\n\nI got a woman...
# 3    Yellow LyricsIn the beginning--\nOh, long befo...
# 4    Green LyricsAs an intellectual vibration smack...
# ..                                                 ...
# 252  Plain As Your Eyes Can See LyricsI have decide...
# 253  One Beer Lyrics\nI get no kick from champagne\...
# 254  Rapp Snitch Knishes Lyrics\nYo! (Yo!)\nMF DOOM...
# 255  That’s That Lyrics\nAlready woke, spared a jok...
# 256  Fresh, Wild, Fly and Bold Lyrics\nWell, I'm fr...
#
#                                            description       release date
# 0    This tongue and cheek verbal duel of a couple ...        August 1961
# 1    Written by Hoagy Carmichael and Stuart Gorrell...     September 1960
# 2    Ray Charles released “I’ve Got a Woman” as a s...      December 1954
# 3                                                    ?    January 1, 1966
# 4                                                    ?    January 1, 1966
# ..                                                 ...                ...
# 252  By many accounts, some of which are in the lin...               1969
# 253  The fourth song from MF DOOM’s MM.. FOOD?, whi...     March 30, 2004
# 254  DOOM and Fantastik talk about how foolish it i...  November 16, 2004
# 255  This song is often regarded as one of DOOM’s m...     March 24, 2009
# 256  A record that doesn’t lack in self-confidence,...               1984
#
# [257 rows x 5 columns]

# %%
data.to_csv("spotify_lyrics.csv", index=False)
